# %%
import sys
import subprocess

# Check if PyWavelets is installed, if not, install it
if 'pywt' not in sys.modules:
    print("PyWavelets not found. Installing...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "PyWavelets"])
    print("PyWavelets installed successfully.")

import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import MobileNet, VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, AveragePooling2D
import os
from google.colab import drive
from scipy.signal import welch
from scipy.stats import skew, kurtosis
from pywt import wavedec
# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# PyWavelets not found. Installing...
# PyWavelets installed successfully.
# Mounted at /content/drive

# %%
def get_valid_directory():
    while True:
        directory = 'My Drive/Bonn dataset'
        full_path = os.path.join('/content/drive', directory)
        if os.path.isdir(full_path):
            return full_path
        else:
            print(f"The directory '{full_path}' does not exist. Please try again.")

def load_eeg_data(file_path):
    try:
        data = np.loadtxt(file_path)
        print(f"Loaded data from {file_path}, shape: {data.shape}")

        if len(data) != 4097:
            print(f"Unexpected data length in {file_path}. Expected 4097, got {len(data)}")
            return None

        padded_data = np.pad(data, (0, 4225 - 4097), 'constant')
        data_2d = padded_data.reshape(1, 65, 65, 1)
        return data_2d, data  # Return both 2D and 1D data
    except Exception as e:
        print(f"Error loading file {file_path}: {str(e)}")
        return None, None

# %%
def create_lenet():
    model = Sequential([
        Conv2D(6, kernel_size=5, activation='relu', input_shape=(65, 65, 1)),
        AveragePooling2D(pool_size=(2, 2)),
        Conv2D(16, kernel_size=5, activation='relu'),
        AveragePooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(120, activation='relu'),
        Dense(84, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# %%
def extract_features(data, model):
    try:
        feature_extractor = tf.keras.Model(inputs=model.inputs, outputs=model.layers[-2].output)
        features = feature_extractor.predict(data)
        return features
    except Exception as e:
        print(f"Error extracting features: {str(e)}")
        return None

def extract_statistical_features(signal):
    return [
        np.mean(signal),
        np.std(signal),
        np.min(signal),
        np.max(signal),
        np.median(signal),
        skew(signal),
        kurtosis(signal),
        np.mean(np.abs(np.diff(signal))),  # Mean absolute difference
        np.sum(np.abs(signal) ** 2) / len(signal),  # Energy
        np.sum(np.abs(signal)) / len(signal),  # Average amplitude
    ]

def extract_frequency_features(signal, fs=173.61):
    f, psd = welch(signal, fs, nperseg=len(signal)//2)
    total_power = np.sum(psd)
    return [
        np.sum(psd[(f >= 0.5) & (f <= 4)]) / total_power,     # Delta band power (relative)
        np.sum(psd[(f > 4) & (f <= 8)]) / total_power,        # Theta band power (relative)
        np.sum(psd[(f > 8) & (f <= 13)]) / total_power,       # Alpha band power (relative)
        np.sum(psd[(f > 13) & (f <= 30)]) / total_power,      # Beta band power (relative)
        np.sum(psd[(f > 30) & (f <= 100)]) / total_power,     # Gamma band power (relative)
        np.mean(f * psd) / total_power,  # Spectral centroid
        np.sqrt(np.sum(f**2 * psd) / np.sum(psd)),  # Spectral spread
        -np.sum(psd * np.log2(psd + 1e-10)) / np.log2(len(psd)),  # Spectral entropy
    ]

def extract_wavelet_features(signal, wavelet='db4', level=5):
    coeffs = wavedec(signal, wavelet, level=level)
    return [np.mean(np.abs(c)) for c in coeffs] + [np.std(c) for c in coeffs]

# %%
def process_file(file_path, mobilenet, vgg16, lenet, category, save_dir):
    try:
        print(f"Processing file: {file_path}")
        print(f"Category: {category}")
        print(f"Save directory: {save_dir}")

        eeg_data_2d, eeg_data_1d = load_eeg_data(file_path)
        if eeg_data_2d is not None and eeg_data_1d is not None:
            # Preprocess data for MobileNet and VGG16
            eeg_data_rgb = np.repeat(eeg_data_2d, 3, axis=-1)  # Convert to RGB
            eeg_data_rgb = tf.image.resize(eeg_data_rgb, (224, 224))  # Resize to 224x224

            # Extract features
            mobilenet_features = extract_features(eeg_data_rgb, mobilenet)
            vgg16_features = extract_features(eeg_data_rgb, vgg16)
            lenet_features = extract_features(eeg_data_2d, lenet)

            # Extract additional features
            statistical_features = extract_statistical_features(eeg_data_1d)
            frequency_features = extract_frequency_features(eeg_data_1d)
            wavelet_features = extract_wavelet_features(eeg_data_1d)

            if all([mobilenet_features is not None, vgg16_features is not None, lenet_features is not None]):
                # Combine all features
                all_features = np.concatenate([
                    mobilenet_features.flatten(),
                    vgg16_features.flatten(),
                    lenet_features.flatten(),
                    statistical_features,
                    frequency_features,
                    wavelet_features
                ])

                # Save the features to a .npz file
                file_name = os.path.basename(file_path).replace('.txt', '.npz')
                save_path = os.path.join(save_dir, file_name)
                np.savez(save_path, features=all_features, category=category)
                print(f"Saved features to {save_path}")
                print(f"Total number of features: {len(all_features)}")
            else:
                print(f"Failed to extract features for {file_path}")
        else:
            print(f"Failed to load data from {file_path}")

    except Exception as e:
        print(f"Error processing file {file_path}: {str(e)}")
    finally:
        tf.keras.backend.clear_session()  # Clear session to free up memory

# %%
def main():
    try:
        # Get the correct directory path from the user
        data_dir = get_valid_directory()

        # Create folders to save the processed data
        save_dir_base = '/content/drive/MyDrive/Bonn_processed5'
        save_dir_normal = os.path.join(save_dir_base, 'Normal')
        save_dir_interictal = os.path.join(save_dir_base, 'Interictal')
        save_dir_ictal = os.path.join(save_dir_base, 'Ictal')
        os.makedirs(save_dir_normal, exist_ok=True)
        os.makedirs(save_dir_interictal, exist_ok=True)
        os.makedirs(save_dir_ictal, exist_ok=True)

        # Load pre-trained models
        mobilenet = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        lenet = create_lenet()

        # Map folder names to categories
        category_map = {
            'Z(a)': 'Normal',
            'O(b)': 'Normal',
            'N(c)': 'Interictal',
            'F(d)': 'Ictal',
            'S(e)': 'Ictal'
        }

        # Walk through the dataset directories
        for root, dirs, files in os.walk(data_dir):
            folder_name = os.path.basename(root)
            category = category_map.get(folder_name)

            if category:
                # Set save directory based on the category
                if category == 'Normal':
                    save_dir = save_dir_normal
                elif category == 'Interictal':
                    save_dir = save_dir_interictal
                elif category == 'Ictal':
                    save_dir = save_dir_ictal
                else:
                    print(f"Unknown category: {category}")
                    continue

                print(f"Processing folder: {folder_name} (Category: {category})")

                for file in files:
                    file_path = os.path.join(root, file)
                    # Make file extension check case-insensitive
                    if os.path.exists(file_path) and file.lower().endswith('.txt'):
                        print(f"Processing file: {file_path}")
                        process_file(file_path, mobilenet, vgg16, lenet, category, save_dir)
                    else:
                        print(f"File {file_path} does not exist or is not accessible.")
            else:
                print(f"Skipping folder: {folder_name} (No matching category)")

    except Exception as e:
        print(f"An error occurred in the main function: {str(e)}")



if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Skipping folder: Bonn dataset (No matching category)
# Processing folder: N(c) (Category: Interictal)
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N093.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N093.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N093.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N093.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N087.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N087.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N087.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b0f441fc310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b0f3c29c700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N087.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N095.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N095.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N095.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N095.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N001.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N001.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N001.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N001.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N084.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N084.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N084.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 724ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N084.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N085.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N085.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N085.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 817ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N085.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N097.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N097.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N097.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N097.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N090.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N090.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N090.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N090.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N098.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N098.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N098.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N098.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N086.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N086.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N086.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N086.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N099.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N099.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N099.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N099.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N089.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N089.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N089.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N089.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N096.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N096.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N096.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N096.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N094.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N094.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N094.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N094.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N088.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N088.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N088.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 762ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N088.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N092.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N092.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N092.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N092.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N083.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N083.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N083.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N083.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N091.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N091.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N091.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N091.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N080.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N080.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N080.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N080.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N067.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N067.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N067.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 774ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N067.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N061.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N061.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N061.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 772ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N061.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N063.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N063.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N063.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N063.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N072.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N072.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N072.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N072.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N071.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N071.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N071.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 758ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N071.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N077.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N077.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N077.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 729ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N077.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N073.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N073.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N073.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N073.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N055.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N055.TXT
# Category: Interictal
# Save directory: /content/drive/MyDrive/Bonn_processed5/Interictal
# Loaded data from /content/drive/My Drive/Bonn dataset/N(c)/N055.TXT, shape: (4097,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 765ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Saved features to /content/drive/MyDrive/Bonn_processed5/Interictal/N055.TXT
# Total number of features: 150642
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/N065.TXT
# Processing file: /content/drive/My Drive/Bonn dataset/N(c)/